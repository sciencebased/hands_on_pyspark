# %% [markdown]
# Whats new in spark?
#
# Spark connect: Client/Server architecture for Spark, allowing remote execution of Spark jobs.
# #Expanded SQL functionality: New SQL functions and improved performance for SQL queries.
#
# #English SDK
# #

# %% [markdown]
# English SDK

# %%
transformed_df = revenue_df.ai.transform("What is the revenue for each product category in the last quarter?")

# %% [markdown]
# List of the new features

# %% [markdown]
# - Better error handling in SQL-style queries
# - Invalid casts
# - Missing data throws error now
# - You can disable ANSI
# - Better support for semi-structured data (JSON / XML)
# - parse_json (raw json - VARIANT)
# - variant_get, try_variant_get
# - COLLATION support
# - Better handling of sorting and comparisons
# - Can be baked into the table definition
# - Specify the session level
# - Data source API's in python

# %% [markdown]
# Notes of the course

# %% [markdown]
# - Legacy RDD is optional (Unless you need to support legacy code)
# - Dataframes keeps the same
# - Delta lake 4.0 suport
# - Java 17 by default
# - Windows require Hadoop
