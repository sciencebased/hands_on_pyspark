# %% [markdown]
# A fast general engine for large computing

# %% [markdown]
# content/images/03.png

# %% [markdown]
# Keyconcept:

# %% [markdown]
# RDD: Resilient distribuited dataset

# %% [markdown]
# # Components of spark

# %% [markdown]
# - Spark streaming: Real time web servers
# - Spark SQL: SQL on top
# - MLLib: Run models
# - GraphX: Graph info, network theories, etc

# %% [markdown]
# # Why python?

# %% [markdown]
# - No need to compile, manage dependencies, etc
# - Less coding overhead
# - You might already know python
# - let us focus on the concepts instead of a new language

# %% [markdown]
# ## But

# %% [markdown]
# - Scala is probably a more popular choice with spark
# - Spark is built in Scala, so coding in Scala is "native" to spark
# - New features, libraries tend to be Scala first

# %% [markdown]
# ## Good news

# %% [markdown]
# Scala and python looks very similar
